# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("dataset.csv")

# %%
columns_to_drop = list(df.loc[:, "CVA_tenderness":"chief_complaint"].columns) + \
                  list(df.loc[:, "arrival":"VITAMINS"].columns) + \
                  ['lang', 'employStatus', 'insurance_status', 'disposition', 'dispo', 
                   'UTI_diag', 'split', 'alt_diag', 'maritalStatus', 'race']

# Drop all the columns at once, except Urinary_tract_infections
df = df.drop(columns=[col for col in columns_to_drop if col != "Urinary_tract_infections"])

# %%
print(list(df.columns))
# Out:
# ['ID', 'PATID', 'UCX_abnormal', 'ua_bacteria', 'ua_bili', 'ua_blood', 'ua_clarity', 'ua_color', 'ua_epi', 'ua_glucose', 'ua_ketones', 'ua_leuk', 'ua_nitrite', 'ua_ph', 'ua_protein', 'ua_rbc', 'ua_spec_grav', 'ua_urobili', 'ua_wbc', 'age', 'gender', 'ethnicity', 'Urinary_tract_infections', 'abxUTI']

# %%
df = df.drop(df[df['ua_clarity'] == 'not_reported'].index)
df = df.drop(df[df['ua_ph'] == 'not_reported'].index)
df['ua_urobili'] = df['ua_urobili'].replace('not_reported', 'negative')
df['ua_bacteria'] = df['ua_bacteria'].replace('none', 'negative')
df = df.replace('not_reported', 'negative')
df = df[df['age'] <= 60]
df.shape
# Out:
# (39491, 24)

# %%
df.head(20)
# Out:
#     ID  PATID UCX_abnormal ua_bacteria   ua_bili  ua_blood ua_clarity  \
# 4    5      4           no    moderate     small  negative      clear
# 5    6      4          yes         few     small     large  not_clear
# 10  11      9           no         few  negative  negative      clear
# 11  12     10          yes         few  negative     small  not_clear
# 14  15     12           no    negative  negative  negative      clear
# 15  16     13           no    negative  negative  negative      clear
# 16  17     13          yes      marked  negative     small  not_clear
# 17  18     14           no         few  negative  moderate  not_clear
# 19  20     16           no        many     small     large  not_clear
# 21  22     18          yes        many  negative  negative      clear
# 23  24     20           no        many     small  negative  not_clear
# 26  27     22           no    negative  negative     small      clear
# 31  32     24           no    negative  negative  negative  not_clear
# 33  34     25          yes         few  negative  negative  not_clear
# 35  36     27          yes    moderate  negative     large  not_clear
# 38  39     30           no        many  negative  negative  not_clear
# 39  40     31          yes    moderate  negative     small      clear
# 40  41     31          yes         few  negative  negative  not_clear
# 41  42     32           no    negative  negative  negative  not_clear
# 42  43     32          yes         few  negative     small  not_clear
#
#    ua_color    ua_epi ua_glucose  ... ua_protein    ua_rbc ua_spec_grav  \
# 4    orange  negative   negative  ...   moderate     small        1.030
# 5    yellow     large   negative  ...      small  moderate        1.030
# 10   yellow     small   negative  ...   negative  negative        1.011
# 11   yellow  moderate   negative  ...   negative     small        1.025
# 14   yellow  negative   negative  ...   negative  negative        1.012
# 15   yellow  negative   negative  ...   negative  negative        1.012
# 16   yellow     large   negative  ...   negative     small        1.028
# 17   yellow     small   negative  ...   negative  moderate        1.019
# 19      red  moderate   negative  ...      small     large        1.027
# 21   orange  moderate   negative  ...   negative     small        1.007
# 23   yellow     small   negative  ...      small     small        1.027
# 26   yellow  moderate   negative  ...   negative     small        1.005
# 31   yellow  moderate   negative  ...   negative  negative        1.010
# 33   yellow     small   negative  ...   negative     small        1.020
# 35   yellow     small   negative  ...   negative  moderate        1.014
# 38   yellow     small   negative  ...   negative  negative        1.028
# 39   yellow     small   negative  ...   negative     small        1.020
# 40   yellow     small   negative  ...   negative  negative        1.023
# 41   yellow     small   negative  ...   negative  negative        1.017
# 42   yellow  moderate   negative  ...      small     small        1.021
#
#    ua_urobili    ua_wbc age  gender           ethnicity  \
# 4    negative     small  55    Male        Non-Hispanic
# 5    negative     small  47  Female        Non-Hispanic
# 10   negative  moderate  31  Female  Hispanic or Latino
# 11   negative  moderate  54  Female        Non-Hispanic
# 14   negative  negative  24    Male        Non-Hispanic
# 15   negative  negative  24    Male        Non-Hispanic
# 16   negative  moderate  36  Female  Hispanic or Latino
# 17   negative     small  46  Female        Non-Hispanic
# 19   negative     small  52  Female        Non-Hispanic
# 21   negative     small  35  Female        Non-Hispanic
# 23   negative     small  44  Female        Non-Hispanic
# 26   negative  moderate  37  Female        Non-Hispanic
# 31   negative  moderate  30  Female        Non-Hispanic
# 33   negative  moderate  60  Female        Non-Hispanic
# 35   negative  moderate  52  Female        Non-Hispanic
# 38   positive  moderate  24  Female        Non-Hispanic
# 39   negative     large  58  Female        Non-Hispanic
# 40   negative  moderate  26  Female        Non-Hispanic
# 41   negative     small  25  Female        Non-Hispanic
# 42   negative     small  44  Female        Non-Hispanic
#
#    Urinary_tract_infections  abxUTI
# 4                        No      no
# 5                        No      no
# 10                       No     yes
# 11                       No      no
# 14                       No     yes
# 15                       No     yes
# 16                       No     yes
# 17                       No      no
# 19                       No     yes
# 21                       No     yes
# 23                       No      no
# 26                       No     yes
# 31                       No     yes
# 33                       No      no
# 35                       No     yes
# 38                       No     yes
# 39                       No     yes
# 40                       No     yes
# 41                       No      no
# 42                       No      no
#
# [20 rows x 24 columns]

# %%
columns_to_check = ['ua_blood', 'ua_clarity', 'ua_color', 'ua_epi', 'ua_glucose', 
                    'ua_ketones', 'ua_leuk', 'ua_nitrite', 'ua_ph', 'ua_protein', 
                    'ua_rbc', 'ua_wbc', 'ua_bili']

# Filter the DataFrame to exclude rows where any of the columns has the value 'other'
clean_df = df[~df[columns_to_check].isin(['other']).any(axis=1)]


df.shape
# Out:
# (39491, 24)

# %%
yes_no_counts = clean_df['UCX_abnormal'].value_counts()

print(f"Yes: {yes_no_counts.get('yes', 0)}")
print(f"No: {yes_no_counts.get('no', 0)}")
# Out:
# Yes: 6421
# No: 32492

# %%
yes_df = clean_df[clean_df['UCX_abnormal'] == 'yes']
no_df = clean_df[clean_df['UCX_abnormal'] == 'no']

no_df_sampled = no_df.sample(n=20000, random_state=42) 

balanced_df = pd.concat([yes_df, no_df_sampled])
balanced_df = balanced_df.sample(frac=1, random_state=42).reset_index(drop=True)

# %%
yes_no_counts = balanced_df['UCX_abnormal'].value_counts()

print(f"Yes: {yes_no_counts.get('yes', 0)}")
print(f"No: {yes_no_counts.get('no', 0)}")
# Out:
# Yes: 6421
# No: 20000

# %%
total_count = len(balanced_df)
yes_count = 6421
no_count = 20000

# Define 30% of the total rows you want to sample
sample_size = int(0.30 * total_count)

# Calculate the number of 'Yes' and 'No' records to maintain the ratio
yes_ratio = yes_count / total_count
no_ratio = no_count / total_count

yes_sample_size = int(sample_size * yes_ratio)
no_sample_size = int(sample_size * no_ratio)

# Sample the respective number of 'Yes' and 'No' records
yes_sample = df[df['UCX_abnormal'] == 'yes'].sample(n=yes_sample_size, random_state=42)
no_sample = df[df['UCX_abnormal'] == 'no'].sample(n=no_sample_size, random_state=42)

# Combine the 'Yes' and 'No' samples into one DataFrame
test_data = pd.concat([yes_sample, no_sample])

clean_df_reset = balanced_df.reset_index(drop=True)
test_data_reset = test_data.reset_index(drop=True)


train_data = clean_df_reset.drop(index=test_data_reset.index)

# Export the sampled DataFrame to a CSV file
test_data.to_csv('test_data.csv', index=False)
train_data.to_csv('training_data.csv', index=False)

print(f"Sampled dataset with {yes_sample_size} 'Yes' and {no_sample_size} 'No' records has been created and exported.")
# Out:
# Sampled dataset with 1926 'Yes' and 5999 'No' records has been created and exported.

# %%
encoded_training = train_data.copy()
encoded_testing = test_data.copy()

# %%
# Binary Encoding for binary columns
binary_columns = {
    'UCX_abnormal': {'yes': 1, 'no': 0},
    'abxUTI': {'yes': 1, 'no': 0},
    'ua_urobili': {'positive': 1, 'negative': 0},
    'Urinary_tract_infections': {'Yes': 1, 'No': 0} 
}

for col, mapping in binary_columns.items():
    encoded_training[col] = encoded_training[col].map(mapping)
    encoded_testing[col] = encoded_testing[col].map(mapping)

# Ordinal Encoding for columns with natural order
ordinal_mappings = {
    'ua_bacteria': ['negative', 'few', 'moderate', 'marked', 'many'],
    'ua_bili': ['negative', 'small', 'moderate', 'large'],
    'ua_blood': ['negative', 'small', 'moderate', 'large'],
    'ua_clarity': ['clear', 'not_clear'],
    'ua_color': ['colorless', 'yellow', 'amber', 'orange', 'red'],
    'ua_epi': ['negative', 'small', 'moderate', 'large'],
    'ua_glucose': ['negative', 'small', 'moderate', 'large'],
    'ua_ketones': ['negative', 'small', 'moderate', 'large', '4+'],
    'ua_leuk': ['negative', 'small', 'moderate', 'large'],
    'ua_nitrite': ['negative', 'positive', 'other'],
    # 'ua_ph': ['5.0', '5.5', '6.0', '6.5', '7.0', '7.5', '8.0', '8.5', '9.0'],
    'ua_protein': ['negative', 'small', 'moderate', 'large'],
    'ua_rbc': ['negative', 'small', 'moderate', 'large'],
    'ua_wbc': ['negative', 'small', 'moderate', 'large']

}

for col, order in ordinal_mappings.items():
    encoded_training[col] = pd.Categorical(encoded_training[col], categories=order, ordered=True).codes
    encoded_testing[col] = pd.Categorical(encoded_testing[col], categories=order, ordered=True).codes

# One-Hot Encoding for categorical columns without a natural order
one_hot_cols = ['ethnicity']

# Use pd.get_dummies to one-hot encode the specified columns
encoded_training = pd.get_dummies(encoded_training, columns=one_hot_cols)
encoded_testing = pd.get_dummies(encoded_testing, columns=one_hot_cols)

encoded_training['Female'] = encoded_training['gender'].apply(lambda x: True if x == 'Female' else False)
encoded_training = encoded_training.drop(columns=['gender'])

encoded_testing['Female'] = encoded_testing['gender'].apply(lambda x: True if x == 'Female' else False)
encoded_testing = encoded_testing.drop(columns=['gender'])

encoded_training.head(50)
# Out:
#          ID  PATID  UCX_abnormal  ua_bacteria  ua_bili  ua_blood  ua_clarity  \
# 7925  13977   9243             0            1        0         3           0
# 7926    884    576             0            0        0         0           0
# 7927  39389  26105             0            0        0         0           0
# 7928  46117  30879             0            1        0         2           1
# 7929  47879  32042             0            2        0         0           1
# 7930  35212  23265             0            0        0         0           0
# 7931  17511  11589             0            1        0         0           1
# 7932  12789   8425             0            2        0         0           0
# 7933  44991  30095             0            0        0         0           0
# 7934  73107  50391             0            0        0         0           0
# 7935  20056  13246             1            3        0         2           0
# 7936  75680  52154             1            4        0         3           1
# 7937   8301   5445             0            0        0         0           0
# 7938   1091    720             0            1        0         0           1
# 7939   2105   1387             0            0        0         0           0
# 7940  79836  55001             0            0        0         3           1
# 7941  18293  12091             0            0        0         0           0
# 7942  66361  45535             1            0        0         2           1
# 7943  42399  28304             0            1        1         0           1
# 7944   4053   2677             0            2        0         2           0
# 7945  72088  49703             0            0        0         1           1
# 7946  47055  31431             0            0        0         0           0
# 7947  39301  26038             0            0        0         0           0
# 7948  20905  13776             0            0        0         3           0
# 7949  47596  31824             1            4        0         3           1
# 7950   9083   6003             0            1        0         0           0
# 7951  16300  10809             0            2        0         0           0
# 7952  28167  18567             1            4        0         3           0
# 7953  64283  43919             0            1        0         0           0
# 7954  77394  53321             1            4        0         3           1
# 7955  26005  17112             0            0        0         1           0
# 7956  50577  34062             0            1        1         3           1
# 7957  74550  51405             1            4        0         1           1
# 7958  30097  19831             0            1        0         1           0
# 7959  33560  22171             0            0        0         3           1
# 7960  33093  21834             0            0        1         0           0
# 7961  41499  27609             0            0        1         0           1
# 7962  64147  43811             0            4        0         0           1
# 7963   9242   6112             0            0        0         0           0
# 7964  70485  48690             1            2        0         1           1
# 7965  34896  23045             0            0        0         0           0
# 7966  78988  54420             1            1        0         1           1
# 7967  45768  30645             1            1        0         3           1
# 7968  32628  21515             1            4        0         2           1
# 7969  51540  34754             1            4        0         2           1
# 7970  62583  42585             1            2        0         0           1
# 7971  17302  11469             1            4        0         3           1
# 7972  25102  16512             1            4        0         3           1
# 7973  61218  41532             1            0        0         0           1
# 7974   6065   4033             0            1        0         1           1
#
#       ua_color  ua_epi  ua_glucose  ...  ua_wbc  age  \
# 7925         1       1           1  ...       1   53
# 7926         1       0           0  ...       0   50
# 7927         1       0           0  ...       0   26
# 7928         4       0           0  ...       1   43
# 7929         1       3           0  ...       1   24
# 7930         1       0           0  ...       0   55
# 7931         1       3           0  ...       1   44
# 7932         3       1           0  ...       2   23
# 7933         1       1           0  ...       2   43
# 7934         1       0           0  ...       0   54
# 7935         1       1           0  ...       2   35
# 7936         1       2           0  ...       2   49
# 7937         1       0           1  ...       0   52
# 7938         1       1           0  ...       1   58
# 7939         1       0           0  ...       0   52
# 7940         4       2           0  ...       2   39
# 7941         1       1           0  ...       0   45
# 7942         3       0           0  ...       2   41
# 7943         4       2           0  ...       1   23
# 7944         1       1           0  ...       1   43
# 7945         1       1           0  ...       2   30
# 7946         1       0           0  ...       0   28
# 7947         0       1           1  ...       1   34
# 7948         1       0           0  ...       1   52
# 7949         1       1           1  ...       3   38
# 7950         1       1           0  ...       2   58
# 7951         1       2           0  ...       2   45
# 7952         1       2           0  ...       2   54
# 7953         1       0           0  ...       2   58
# 7954         1       2           0  ...       3   19
# 7955         1       1           0  ...       1   35
# 7956         1       0           0  ...       1   19
# 7957         1       1           0  ...       2   58
# 7958         1       0           0  ...       1   46
# 7959         1       2           0  ...       2   38
# 7960         1       0           0  ...       0   55
# 7961         1       2           0  ...       2   44
# 7962         1       3           0  ...       1   33
# 7963         1       1           0  ...       1   43
# 7964         1       2           0  ...       3   23
# 7965         1       1           0  ...       0   59
# 7966         1       3           0  ...       2   25
# 7967         1       1           0  ...       2   54
# 7968         1       1           0  ...       3   46
# 7969         1       2           0  ...       2   39
# 7970         1       3           0  ...       1   33
# 7971         1       2           0  ...       3   22
# 7972         1       1           0  ...       3   18
# 7973         1       3           0  ...       1   21
# 7974         1       2           0  ...       3   22
#
#       Urinary_tract_infections abxUTI  ethnicity_Hispanic or Latino  \
# 7925                         0      1                         False
# 7926                         0      0                         False
# 7927                         0      0                          True
# 7928                         0      0                          True
# 7929                         0      1                         False
# 7930                         0      0                         False
# 7931                         0      0                         False
# 7932                         1      1                         False
# 7933                         0      1                         False
# 7934                         0      0                         False
# 7935                         0      1                         False
# 7936                         0      1                         False
# 7937                         0      0                         False
# 7938                         0      0                          True
# 7939                         0      0                         False
# 7940                         0      0                         False
# 7941                         0      1                         False
# 7942                         0      1                         False
# 7943                         0      0                         False
# 7944                         0      0                          True
# 7945                         0      1                         False
# 7946                         0      1                         False
# 7947                         0      0                         False
# 7948                         0      1                          True
# 7949                         0      1                         False
# 7950                         0      1                         False
# 7951                         0      1                         False
# 7952                         0      1                         False
# 7953                         0      1                         False
# 7954                         0      1                         False
# 7955                         0      0                          True
# 7956                         0      0                         False
# 7957                         0      1                         False
# 7958                         0      0                         False
# 7959                         0      1                         False
# 7960                         0      0                         False
# 7961                         0      0                         False
# 7962                         0      0                         False
# 7963                         0      1                         False
# 7964                         0      1                         False
# 7965                         0      1                         False
# 7966                         1      1                         False
# 7967                         1      1                         False
# 7968                         1      1                         False
# 7969                         0      1                         False
# 7970                         0      0                          True
# 7971                         0      1                         False
# 7972                         0      1                         False
# 7973                         0      0                          True
# 7974                         0      1                          True
#
#       ethnicity_Non-Hispanic  ethnicity_Patient Refused  ethnicity_Unknown  \
# 7925                    True                      False              False
# 7926                    True                      False              False
# 7927                   False                      False              False
# 7928                   False                      False              False
# 7929                    True                      False              False
# 7930                   False                      False              False
# 7931                    True                      False              False
# 7932                    True                      False              False
# 7933                    True                      False              False
# 7934                    True                      False              False
# 7935                    True                      False              False
# 7936                    True                      False              False
# 7937                    True                      False              False
# 7938                   False                      False              False
# 7939                    True                      False              False
# 7940                    True                      False              False
# 7941                    True                      False              False
# 7942                    True                      False              False
# 7943                    True                      False              False
# 7944                   False                      False              False
# 7945                    True                      False              False
# 7946                    True                      False              False
# 7947                    True                      False              False
# 7948                   False                      False              False
# 7949                    True                      False              False
# 7950                    True                      False              False
# 7951                    True                      False              False
# 7952                    True                      False              False
# 7953                    True                      False              False
# 7954                    True                      False              False
# 7955                   False                      False              False
# 7956                   False                      False               True
# 7957                    True                      False              False
# 7958                    True                      False              False
# 7959                    True                      False              False
# 7960                    True                      False              False
# 7961                    True                      False              False
# 7962                    True                      False              False
# 7963                    True                      False              False
# 7964                    True                      False              False
# 7965                    True                      False              False
# 7966                    True                      False              False
# 7967                    True                      False              False
# 7968                    True                      False              False
# 7969                    True                      False              False
# 7970                   False                      False              False
# 7971                    True                      False              False
# 7972                    True                      False              False
# 7973                   False                      False              False
# 7974                   False                      False              False
#
#       ethnicity_negative  Female
# 7925               False    True
# 7926               False   False
# 7927               False   False
# 7928               False   False
# 7929               False    True
# 7930                True   False
# 7931               False    True
# 7932               False    True
# 7933               False    True
# 7934               False   False
# 7935               False    True
# 7936               False    True
# 7937               False    True
# 7938               False    True
# 7939               False   False
# 7940               False    True
# 7941               False   False
# 7942               False    True
# 7943               False    True
# 7944               False    True
# 7945               False    True
# 7946               False    True
# 7947               False   False
# 7948               False   False
# 7949               False   False
# 7950               False   False
# 7951               False    True
# 7952               False    True
# 7953               False   False
# 7954               False    True
# 7955               False    True
# 7956               False   False
# 7957               False   False
# 7958               False    True
# 7959               False    True
# 7960               False   False
# 7961               False   False
# 7962               False    True
# 7963               False   False
# 7964               False    True
# 7965               False    True
# 7966               False    True
# 7967               False    True
# 7968               False    True
# 7969               False    True
# 7970               False    True
# 7971               False    True
# 7972               False    True
# 7973               False    True
# 7974               False    True
#
# [50 rows x 28 columns]

# %%
encoded_testing.to_csv('encoded_testing.csv', index=False)
encoded_training.to_csv('encoded_training.csv', index=False)

# %%
encoded_testing.isnull().sum()
# Out:
# ID                              0
# PATID                           0
# UCX_abnormal                    0
# ua_bacteria                     0
# ua_bili                         0
# ua_blood                        0
# ua_clarity                      0
# ua_color                        0
# ua_epi                          0
# ua_glucose                      0
# ua_ketones                      0
# ua_leuk                         0
# ua_nitrite                      0
# ua_ph                           0
# ua_protein                      0
# ua_rbc                          0
# ua_spec_grav                    0
# ua_urobili                      0
# ua_wbc                          0
# age                             0
# Urinary_tract_infections        0
# abxUTI                          0
# ethnicity_Hispanic or Latino    0
# ethnicity_Non-Hispanic          0
# ethnicity_Patient Refused       0
# ethnicity_Unknown               0
# ethnicity_negative              0
# Female                          0
# dtype: int64
